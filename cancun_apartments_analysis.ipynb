# %% [markdown]
# # Prueba técnica Desarrollador Back End

# %% [markdown]
# ## El nuevo departamento

# %%
from contextlib import closing
from itertools import cycle
import math
import random
import traceback

from bs4 import BeautifulSoup
from lxml.html import fromstring
import pandas as pd
import numpy as np
import requests
from requests import get
from requests.exceptions import RequestException
from sqlalchemy import create_engine

# %%
session = requests.Session()
engine = create_engine('postgresql://postgres:7o46IOLaPI16v3eow@localhost:5432/aparments')
root_url = 'https://www.inmuebles24.com/departamentos-en-venta-en-zona-hotelera.html'

# %% [markdown]
# ## User Agent list

# %%
USER_AGENTS = [
    ('Mozilla/5.0 ' 
     '(X11; Ubuntu; Linux x86_64; rv:53.0) '
     'Gecko/20100101 '
     'Firefox/53.0'),
    ('Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54.0) '
     'Gecko/20100101 '
     'Firefox/54.0'),
    ('Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:59.0) '
     'Gecko/20100101 '
     'Firefox/59.0'),
    ('Mozilla/5.0 (X11; U; Linux x86_64; en-US; rv:1.9.2.4) '
     'Gecko/20100614 '
     'Ubuntu/10.04 (lucid) '
     'Firefox/3.6.4'),
    ('Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15.0) '
     'Gecko/20100101 '
     'Firefox/15.0'),
    ('Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:51.0) '
     'Gecko/20100101 '
     'Firefox/51.0')
]

# %% [markdown]
# ## Rotating Requests through a pool of Proxies

# %%
def get_proxies():
    """Gets a list of proxies from ree-proxy-list.net
    
    Returns
    -------
    set
        a set of strings of proxies
    """
    url = 'https://free-proxy-list.net/'
    response = requests.get(url)
    parser = fromstring(response.text)
    proxies = set()
    for i in parser.xpath('//tbody/tr')[:10]:
        if i.xpath('.//td[7][contains(text(),"yes")]'):
            proxy = ":".join([i.xpath('.//td[1]/text()')[0], i.xpath('.//td[2]/text()')[0]])
            proxies.add(proxy)
    return proxies

# %% [markdown]
# ## Helper functions

# %%
def headers():
    """Creates a header dict with a random user-agent

    Returns
    -------
    dict
        a dict with a rando user aget fro, USER_AGENTS
    """
    user_agent = random.choice(USER_AGENTS) 
    return {'User-Agent': user_agent}

# %%
def random_proxy():
    """Gets and prints the spreadsheet's header columns

    Parameters
    ----------
    file_loc : str
        The file location of the spreadsheet
    print_cols : bool, optional
        A flag used to print the columns to the console (default is
        False)

    Returns
    -------
    list
        a list of strings used that are the header columns
    """
    return random.choice(list(get_proxies()))

# %%
def simple_get(url):
    """Makes a request to the given site

    Parameters
    ----------
    url : str
        The url of the site

    Returns
    -------
    bytes
        The content of the response Response in bytes
    """
    try:
        proxy = random_proxy()
        with closing(get(url, headers=headers(),
                         proxies={"http": proxy, "https": proxy},
                         stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error(f"Error during requests to {url}: {str(e)}")
        return None

# %%
def is_good_response(resp):
    """Verifies is the response is validate
    
    Parameters
    ----------
    resp : request.Response
        The file location of the spreadsheet

    Returns
    -------
    bool
        a boolean, true if the response is validate
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)

# %%
def log_error(e):
    print(e)

# %%
def split_price(price):
    """Splits the given price in two

    Parameters
    ----------
    price : str
        The price of the apartment with its currency

    Returns
    -------
    tuple
        a tuple of two values, the currency and the price of the apartment
    """
    splitted_price = price.split()
    return splitted_price[0], splitted_price[1]

# %%
def format_price(price):
    """Converts the given price to int 

    Parameters
    ----------
    price : bs4.element.Tag
        The price tag

    Returns
    -------
    int
        the actual price of the apartment as int value
    """
    currency, amount = split_price(price.text)
    if currency == 'USD':
        amount = int(convert_usd_to_mxn(int("".join(amount.split(',')))))
    else:
        amount = int("".join(amount.split(',')))
    return amount

# %%
def convert_usd_to_mxn(amount):
    """
    Valor al día de 31/03/2019
    """
    return amount * 19.35

# %%
def format_title(title):   
    """Converts the title of the aparment to str, removing \t and \n characters

    Parameters
    ----------
    price : bs4.element.Tag
        The title tag

    Returns
    -------
    str
        the name of the apartment as str value, without strange characters
    """
    
    return title.text.replace('\t', '').replace('\n', '')

# %%
def get_square_meters(square_meters_tag):
    """Converts the square meters of the aparyment to int, removing the 'm2' and 'construidos' words 

    Parameters
    ----------
    price : bs4.element.Tag
        The square meter tag

    Returns
    -------
    int
        the square meters of the apartment as int value
    """
    return int(square_meters_tag.text.split()[0])

# %% [markdown]
# ## Get the HTML content of the page

# %%
response = simple_get(root_url)

if response is not None:
        html = BeautifulSoup(response, "html5lib")

response is None
# Out:
# False

# %% [markdown]
# ## Get the main list

# %%
main_list = html.find_all('li', attrs={"class": "aviso aviso-desktop aviso--superdestacado"})
main_list
# Out:
# [<li class="aviso aviso-desktop aviso--superdestacado" data-aviso="54119474" data-href="/propiedades/sensacional-departamento-en-zona-hotelera-de-cancun-54119474.html" data-isdesarrollo="false" data-tipoaviso="Clasificados  superdestacado" id="aviso-54119474">
#
#  	<input class="avisoInmoImg" data-error="//img10.naventcdn.com/css/img/placeholder-img.png" name="" type="hidden" value=" https://img10.naventcdn.com/empresas/18/00/50/17/57/42/130x70/logo_tropica-realty_0.jpg"/>
#  	<input class="avisoInmoCertif" name="" type="hidden" value=""/>
#  	<input class="avisoInmoTitle" name="" type="hidden" value="TROPICA REALTY"/>
#  	<input class="avisoInmoPhone" name="" type="hidden" value="9981 "/>
#  	<input class="avisoInmoTipoAnunciante" name="" type="hidden" value="clasificados"/>
#  	<input class="avisoPrecio" name="" type="hidden" value="USD 1,299,000"/>
#
#  	<div class="aviso-tags">
#  			<span class="aviso-tags-superdestacado">
#
#  				Super destacado
#  			</span>
#  	</div>
#  	<div class="aviso-data">
#  		<div class="aviso-media">
#  			<span class="aviso-fav" data-aviso-id="54119474" data-component="nvt-add-fav">
#  				<i class="icon-fav"></i>
#  			</span>
#  			<div class="aviso-media-labels">
#  				<span class="aviso-media-labels-count label label-black label-black--transparent" data-count="24">1/24</span>
#
#
#  			</div>
#
#
#  <div class="picture-slider" data-aviso="54119474">
#  	<div class="listSlider loadThis js-TieneMapa js-SlideMapaInactivo" data-index-imagen="1" data-url-mapa="//maps.google.com/maps/api/staticmap?center=21.1297836906509,-86.74949699975281&amp;zoom=15&amp;markers=21.1297836906509,-86.74949699975281&amp;channel=I24&amp;size=720x532&amp;sensor=true&amp;scale=2&amp;key=AIzaSyBfTOxuYEmbL50_1P4KU8GI8toKT539agI&amp;signature=BDOWLO-kOorRgXF2f4SkANXw16w=">
#  		<div class="slide-content">
#  			<a class="jsUrlFichaMap map-slide display-block overslide-btn-contac" href="/propiedades/sensacional-departamento-en-zona-hotelera-de-cancun-54119474.html#map">
#  				<img alt="" class="rsImg rsMainSlideImage mapImage" id="imgMap-54119474" src="..."/>
#  			</a>
#  		</div>
#
#  		<div class="slide-content">
#  			<img alt="Sensacional Departamento en Zona Hotelera de Cancun" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/122821597.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento de 4 habitaciones en Cancún" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269104.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta de 4 habitaciones en Zona Hotelera" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269105.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Incomparable, bello y luminoso apartamento de 4 habitaciones amueblado y complet" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269106.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta, 285 m2 de 4 habitaciones" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269107.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento, 285 m2 en Venta en Zona Hotelera" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269108.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta en Zona Hotelera en Cancún" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269109.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento de 4 habitaciones en Venta USD 1,299,000" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269110.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Sensacional Departamento en Zona Hotelera de Cancun - TROPICA REALTY" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269111.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta de 4 habitaciones" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269112.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Sensacional Departamento en Zona Hotelera de Cancun" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269113.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento de 4 habitaciones en Cancún" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269114.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta de 4 habitaciones en Zona Hotelera" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269115.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Incomparable, bello y luminoso apartamento de 4 habitaciones amueblado y complet" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269116.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta, 285 m2 de 4 habitaciones" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269117.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento, 285 m2 en Venta en Zona Hotelera" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269118.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta en Zona Hotelera en Cancún" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269119.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento de 4 habitaciones en Venta USD 1,299,000" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269120.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Sensacional Departamento en Zona Hotelera de Cancun - TROPICA REALTY" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269121.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta de 4 habitaciones" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269122.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Sensacional Departamento en Zona Hotelera de Cancun" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269123.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento de 4 habitaciones en Cancún" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269124.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta de 4 habitaciones en Zona Hotelera" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269125.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Incomparable, bello y luminoso apartamento de 4 habitaciones amueblado y complet" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/93269126.jpg" src="..."/>
#  		</div>
#  	</div>
#  </div>
#  <div class="aviso-main-photo-container">
#  		<button aria-label="previous" class="flickity-prev-next-button flickity-prev-next-button-temp previous" type="button"><svg viewBox="0 0 100 100"><path class="arrow" d="M 25,50 L 60,85 L 65,75 L 40,50  L 65,25 L 60,15 Z"></path></svg></button>
#  			<img class="aviso-main-photo lazyload" data-src="https://img10.naventcdn.com/avisos/18/00/54/11/94/74/360x266/122821597.jpg" src="..."/>
#  		<button aria-label="next" class="flickity-prev-next-button flickity-prev-next-button-temp next" type="button"><svg viewBox="0 0 100 100"><path class="arrow" d="M 25,50 L 60,85 L 65,75 L 40,50  L 65,25 L 60,15 Z" transform="translate(100, 100) rotate(180) "></path></svg></button>
#  	</div>
#
#
#  		</div>
#  		<div class="aviso-data-price">
#
#  	<div class="aviso-data-price-content">
#
#  	<span class="aviso-data-price-value">USD 1,299,000</span>
#
#
#
#
#  </div>
#
#  		</div>
#  	</div><!--
#  	--><div class="aviso-data aviso-data--right">
#  		<div class="aviso-data-content">
#  			<div class="aviso-data-head">
#  				<div class="aviso-data-text">
#  					<h4 class="aviso-data-title">
#  						<a class="dl-aviso-a" href="/propiedades/sensacional-departamento-en-zona-hotelera-de-cancun-54119474.html" target="_blank" title="Sensacional Departamento En Zona Hotelera de Cancun">
#  							Sensacional Departamento en Zona Hotelera de Cancun
#  						</a>
#  					</h4>
#  					<span class="aviso-data-location dl-aviso-link">
#  						Blvd Kukulcan KM 9.5
#  							-
#  						<span>Zona Hotelera, Cancún</span>
#  					</span>
#  				</div>
#  				<div class="aviso-data-logos">
#  						<div class="aviso-data-logo">
#  							<img class="logo-inmobiliaria lazyload" data-src="https://img10.naventcdn.com/empresas/18/00/50/17/57/42/130x70/logo_tropica-realty_0.jpg" height="30" onerror="this.src='//img10.naventcdn.com/css/img/placeholder-img.png'" src="..." width="60"/>
#  						</div>
#
#  				</div>
#  			</div>
#  			<ul class="aviso-data-features dl-aviso-link">
#  							<li class="aviso-data-features-value">
#  								285 m²
#  								<span>
#  									construidos
#  								</span>
#  							</li>
#  						<li class="aviso-data-features-value">
#  							4
#  							<span>
#  									Recámaras
#  							</span>
#  						</li>
#  						<li class="aviso-data-features-value">
#  							4
#  							<span>
#  									Baños
#  							</span>
#  						</li>
#  			</ul>
#  			<p class="aviso-data-description dl-aviso-link">
#  				Incomparable, bello y luminoso apartamento de 4 habitaciones amueblado y completamente remodelado de alta gama con dos estacionamientos techados. Central y convenientemente ubicado en el km 9. 5 de la Zona Hotelera de Cancún en el "Residencial Bay View Grand". Contáctenos hoy mismo para una cita personalizada y mas detalles de la propiedad. Garantizado superara sus expectativas!
#  			</p>
#
#  			<div class="aviso-data-extra">
#  				<ul class="aviso-data-extra-ul">
#
#  				</ul>
#  			</div>
#  			<div class="aviso-data-cta">
#  				<div class="pull-right">
#  					<!-- primary CTA -->
#
#  					<button class="contactar-btn btn btn-card btn-aviso js-contact" data-aviso-id="54119474" data-tipo-anunciante="clasificados">
#  						Contactar
#  					</button>
#
#  					<button class="recontactar-btn btn btn-card btn-aviso js-contact" data-aviso-id="54119474" data-tipo-anunciante="clasificados">
#  						volver a contactar
#  					</button>
#  					<!-- directorio CTA -->
#  					<a class="btn btn-card btn-inmo dl-aviso-link" href="/propiedades/sensacional-departamento-en-zona-hotelera-de-cancun-54119474.html" title="Sensacional Departamento En Zona Hotelera de Cancun">
#  						ver detalles
#  					</a>
#  				</div>
#  			</div>
#  		</div>
#  	</div>
#  </li>,
#  <li class="aviso aviso-desktop aviso--superdestacado" data-aviso="55590484" data-href="/propiedades/departamento-en-venta-en-poktapok-55590484.html" data-isdesarrollo="false" data-tipoaviso="Clasificados  superdestacado" id="aviso-55590484">
#
#  	<input class="avisoInmoImg" data-error="//img10.naventcdn.com/css/img/placeholder-img.png" name="" type="hidden" value=" https://img10.naventcdn.com/empresas/18/00/50/12/60/06/80X48/logo_caribbean-realtors_1526582849916.jpg"/>
#  	<input class="avisoInmoCertif" name="" type="hidden" value=""/>
#  	<input class="avisoInmoTitle" name="" type="hidden" value="Caribbean Realtors"/>
#  	<input class="avisoInmoPhone" name="" type="hidden" value="998 1"/>
#  	<input class="avisoInmoTipoAnunciante" name="" type="hidden" value="clasificados"/>
#  	<input class="avisoPrecio" name="" type="hidden" value="MN 5,300,000"/>
#
#  	<div class="aviso-tags">
#  			<span class="aviso-tags-superdestacado">
#
#  				Super destacado
#  			</span>
#  	</div>
#  	<div class="aviso-data">
#  		<div class="aviso-media">
#  			<span class="aviso-fav" data-aviso-id="55590484" data-component="nvt-add-fav">
#  				<i class="icon-fav"></i>
#  			</span>
#  			<div class="aviso-media-labels">
#  				<span class="aviso-media-labels-count label label-black label-black--transparent" data-count="8">1/8</span>
#
#
#  			</div>
#
#
#  <div class="picture-slider" data-aviso="55590484">
#  	<div class="listSlider loadThis js-TieneMapa js-SlideMapaInactivo" data-index-imagen="1" data-url-mapa="//maps.google.com/maps/api/staticmap?center=21.1279956,-86.7644738&amp;zoom=15&amp;markers=21.1279956,-86.7644738&amp;channel=I24&amp;size=720x532&amp;sensor=true&amp;scale=2&amp;key=AIzaSyBfTOxuYEmbL50_1P4KU8GI8toKT539agI&amp;signature=3RuCF3l_SjTehTHmgspZb74oCsg=">
#  		<div class="slide-content">
#  			<a class="jsUrlFichaMap map-slide display-block overslide-btn-contac" href="/propiedades/departamento-en-venta-en-poktapok-55590484.html#map">
#  				<img alt="" class="rsImg rsMainSlideImage mapImage" id="imgMap-55590484" src="..."/>
#  			</a>
#  		</div>
#
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta en Poktapok" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/59/04/84/360x266/117932844.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento de 2 habitaciones en Cancún" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/59/04/84/360x266/117932845.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta de 2 habitaciones en Zona Hotelera" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/59/04/84/360x266/117932846.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta en PoktapokDepartamento en venta en Zona Hotelera Vista a " data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/59/04/84/360x266/117932847.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta, 140 m2 de 2 habitaciones" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/59/04/84/360x266/117932848.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento, 140 m2 en Venta en Zona Hotelera" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/59/04/84/360x266/117932849.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta en Zona Hotelera en Cancún" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/59/04/84/360x266/117932850.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento de 2 habitaciones en Venta MN 5,300,000" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/59/04/84/360x266/117932851.jpg" src="..."/>
#  		</div>
#  	</div>
#  </div>
#  <div class="aviso-main-photo-container">
#  		<button aria-label="previous" class="flickity-prev-next-button flickity-prev-next-button-temp previous" type="button"><svg viewBox="0 0 100 100"><path class="arrow" d="M 25,50 L 60,85 L 65,75 L 40,50  L 65,25 L 60,15 Z"></path></svg></button>
#  			<img class="aviso-main-photo lazyload" data-src="https://img10.naventcdn.com/avisos/18/00/55/59/04/84/360x266/117932844.jpg" src="..."/>
#  		<button aria-label="next" class="flickity-prev-next-button flickity-prev-next-button-temp next" type="button"><svg viewBox="0 0 100 100"><path class="arrow" d="M 25,50 L 60,85 L 65,75 L 40,50  L 65,25 L 60,15 Z" transform="translate(100, 100) rotate(180) "></path></svg></button>
#  	</div>
#
#
#  		</div>
#  		<div class="aviso-data-price">
#
#  	<div class="aviso-data-price-content">
#
#  	<span class="aviso-data-price-value">MN 5,300,000</span>
#
#
#
#
#  </div>
#
#  		</div>
#  	</div><!--
#  	--><div class="aviso-data aviso-data--right">
#  		<div class="aviso-data-content">
#  			<div class="aviso-data-head">
#  				<div class="aviso-data-text">
#  					<h4 class="aviso-data-title">
#  						<a class="dl-aviso-a" href="/propiedades/departamento-en-venta-en-poktapok-55590484.html" target="_blank" title="Departamento en Venta en Poktapok">
#  							Departamento en Venta en Poktapok
#  						</a>
#  					</h4>
#  					<span class="aviso-data-location dl-aviso-link">
#  						Departamento en Venta en Poktapok
#  							-
#  						<span>Zona Hotelera, Cancún</span>
#  					</span>
#  				</div>
#  				<div class="aviso-data-logos">
#  						<div class="aviso-data-logo">
#  							<img class="logo-inmobiliaria lazyload" data-src="https://img10.naventcdn.com/empresas/18/00/50/12/60/06/80X48/logo_caribbean-realtors_1526582849916.jpg" height="30" onerror="this.src='//img10.naventcdn.com/css/img/placeholder-img.png'" src="..." width="60"/>
#  						</div>
#
#  				</div>
#  			</div>
#  			<ul class="aviso-data-features dl-aviso-link">
#  							<li class="aviso-data-features-value">
#  								140 m²
#  								<span>
#  									construidos
#  								</span>
#  							</li>
#  						<li class="aviso-data-features-value">
#  							2
#  							<span>
#  									Recámaras
#  							</span>
#  						</li>
#  						<li class="aviso-data-features-value">
#  							2
#  							<span>
#  									Baños
#  							</span>
#  						</li>
#  			</ul>
#  			<p class="aviso-data-description dl-aviso-link">
#  				Departamento en Venta en PoktapokDepartamento en venta en Zona Hotelera Vista a la laguna 2 recamaras con baño Sala de tv. O estudio Sala, comedor, cocina integral Cuarto de lavado Estacionamiento para 2 autos Áreas comunes con alberca jardín y muelle Seguridad las 24 hrs 140 m2 $5, 300, 000Tonalli GarciaCel. <span class="descripcionDatosAnunciante"><button class="btn btn-link js-verDatos" href="#">Ver datos</button></span>Caribbean RealtorsEspecializados en el sector inmobiliario de lujo, orientados al cliente y con la mas alta tecnología. El mejor grupo interdisciplinario de profesionales a su servicio: asesores inmobiliarios certificados, abogados, contador fiscalista, gestores, perito valuador, etc…. Miembros de la Asociación Mexicana de Profesionales inmobiliarios "A. M. P. I" Member of the National Association of realtors®Matricula: cre<span class="descripcionDatosAnunciante"><button class="btn btn-link js-verDatos" href="#">Ver datos</button></span>Z6mr<span class="descripcionDatosAnunciante"><button class="btn btn-link js-verDatos" href="#">Ver datos</button></span>
#  			</p>
#
#  			<div class="aviso-data-extra">
#  				<ul class="aviso-data-extra-ul">
#
#  				</ul>
#  			</div>
#  			<div class="aviso-data-cta">
#  				<div class="pull-right">
#  					<!-- primary CTA -->
#
#  					<button class="contactar-btn btn btn-card btn-aviso js-contact" data-aviso-id="55590484" data-tipo-anunciante="clasificados">
#  						Contactar
#  					</button>
#
#  					<button class="recontactar-btn btn btn-card btn-aviso js-contact" data-aviso-id="55590484" data-tipo-anunciante="clasificados">
#  						volver a contactar
#  					</button>
#  					<!-- directorio CTA -->
#  					<a class="btn btn-card btn-inmo dl-aviso-link" href="/propiedades/departamento-en-venta-en-poktapok-55590484.html" title="Departamento en Venta en Poktapok">
#  						ver detalles
#  					</a>
#  				</div>
#  			</div>
#  		</div>
#  	</div>
#  </li>,
#  <li class="aviso aviso-desktop aviso--superdestacado" data-aviso="55819433" data-href="/propiedades/departamentos-en-venta-en-cancun-zona-hotelera-55819433.html" data-isdesarrollo="false" data-tipoaviso="Clasificados  superdestacado" id="aviso-55819433">
#
#  	<input class="avisoInmoImg" data-error="//img10.naventcdn.com/css/img/placeholder-img.png" name="" type="hidden" value=" https://img10.naventcdn.com/empresas/18/00/50/12/60/06/80X48/logo_caribbean-realtors_1526582849916.jpg"/>
#  	<input class="avisoInmoCertif" name="" type="hidden" value=""/>
#  	<input class="avisoInmoTitle" name="" type="hidden" value="Caribbean Realtors"/>
#  	<input class="avisoInmoPhone" name="" type="hidden" value="998 1"/>
#  	<input class="avisoInmoTipoAnunciante" name="" type="hidden" value="clasificados"/>
#  	<input class="avisoPrecio" name="" type="hidden" value="USD 340,000"/>
#
#  	<div class="aviso-tags">
#  			<span class="aviso-tags-superdestacado">
#
#  				Super destacado
#  			</span>
#  	</div>
#  	<div class="aviso-data">
#  		<div class="aviso-media">
#  			<span class="aviso-fav" data-aviso-id="55819433" data-component="nvt-add-fav">
#  				<i class="icon-fav"></i>
#  			</span>
#  			<div class="aviso-media-labels">
#  				<span class="aviso-media-labels-count label label-black label-black--transparent" data-count="16">1/16</span>
#
#
#  			</div>
#
#
#  <div class="picture-slider" data-aviso="55819433">
#  	<div class="listSlider loadThis js-TieneMapa js-SlideMapaInactivo" data-index-imagen="1" data-url-mapa="//maps.google.com/maps/api/staticmap?center=21.1302272,-86.7626738&amp;zoom=15&amp;markers=21.1302272,-86.7626738&amp;channel=I24&amp;size=720x532&amp;sensor=true&amp;scale=2&amp;key=AIzaSyBfTOxuYEmbL50_1P4KU8GI8toKT539agI&amp;signature=mohVifuDAuquZpFzeAJaARW_vBA=">
#  		<div class="slide-content">
#  			<a class="jsUrlFichaMap map-slide display-block overslide-btn-contac" href="/propiedades/departamentos-en-venta-en-cancun-zona-hotelera-55819433.html#map">
#  				<img alt="" class="rsImg rsMainSlideImage mapImage" id="imgMap-55819433" src="..."/>
#  			</a>
#  		</div>
#
#  		<div class="slide-content">
#  			<img alt="Departamentos en Venta en Cancun Zona Hotelera" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554233.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento de 2 habitaciones en Cancún" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554216.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta de 2 habitaciones en Zona Hotelera" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554218.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Magnifico departamento en isla bonita Pok Ta PokConstruccion 142m2Ubicado en el " data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554219.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta, 142 m2 de 2 habitaciones" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554220.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento, 142 m2 en Venta en Zona Hotelera" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554226.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta en Zona Hotelera en Cancún" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554222.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento de 2 habitaciones en Venta USD 340,000" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554225.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamentos en Venta en Cancun Zona Hotelera - Caribbean Realtors" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554227.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta de 2 habitaciones" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554228.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamentos en Venta en Cancun Zona Hotelera" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554229.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento de 2 habitaciones en Cancún" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554223.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta de 2 habitaciones en Zona Hotelera" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554230.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Magnifico departamento en isla bonita Pok Ta PokConstruccion 142m2Ubicado en el " data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554231.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento en Venta, 142 m2 de 2 habitaciones" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554232.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Departamento, 142 m2 en Venta en Zona Hotelera" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554234.jpg" src="..."/>
#  		</div>
#  	</div>
#  </div>
#  <div class="aviso-main-photo-container">
#  		<button aria-label="previous" class="flickity-prev-next-button flickity-prev-next-button-temp previous" type="button"><svg viewBox="0 0 100 100"><path class="arrow" d="M 25,50 L 60,85 L 65,75 L 40,50  L 65,25 L 60,15 Z"></path></svg></button>
#  			<img class="aviso-main-photo lazyload" data-src="https://img10.naventcdn.com/avisos/18/00/55/81/94/33/360x266/121554233.jpg" src="..."/>
#  		<button aria-label="next" class="flickity-prev-next-button flickity-prev-next-button-temp next" type="button"><svg viewBox="0 0 100 100"><path class="arrow" d="M 25,50 L 60,85 L 65,75 L 40,50  L 65,25 L 60,15 Z" transform="translate(100, 100) rotate(180) "></path></svg></button>
#  	</div>
#
#
#  		</div>
#  		<div class="aviso-data-price">
#
#  	<div class="aviso-data-price-content">
#
#  	<span class="aviso-data-price-value">USD 340,000</span>
#
#
#
#
#  </div>
#
#  		</div>
#  	</div><!--
#  	--><div class="aviso-data aviso-data--right">
#  		<div class="aviso-data-content">
#  			<div class="aviso-data-head">
#  				<div class="aviso-data-text">
#  					<h4 class="aviso-data-title">
#  						<a class="dl-aviso-a" href="/propiedades/departamentos-en-venta-en-cancun-zona-hotelera-55819433.html" target="_blank" title="Departamentos en venta en Cancun zona hotelera">
#  							Departamentos en Venta en Cancun Zona Hotelera
#  						</a>
#  					</h4>
#  					<span class="aviso-data-location dl-aviso-link">
#  						Departamentos EN Venta EN Cancun Zona Hotelera
#  							-
#  						<span>Zona Hotelera, Cancún</span>
#  					</span>
#  				</div>
#  				<div class="aviso-data-logos">
#  						<div class="aviso-data-logo">
#  							<img class="logo-inmobiliaria lazyload" data-src="https://img10.naventcdn.com/empresas/18/00/50/12/60/06/80X48/logo_caribbean-realtors_1526582849916.jpg" height="30" onerror="this.src='//img10.naventcdn.com/css/img/placeholder-img.png'" src="..." width="60"/>
#  						</div>
#
#  				</div>
#  			</div>
#  			<ul class="aviso-data-features dl-aviso-link">
#  							<li class="aviso-data-features-value">
#  								142 m²
#  								<span>
#  									construidos
#  								</span>
#  							</li>
#  						<li class="aviso-data-features-value">
#  

#  						ver detalles
#  					</a>
#  				</div>
#  			</div>
#  		</div>
#  	</div>
#  </li>,
#  <li class="aviso aviso-desktop aviso--superdestacado" data-aviso="55172323" data-href="/propiedades/departamento-con-espectacular-vista-a-la-laguna-en-55172323.html" data-isdesarrollo="false" data-tipoaviso="Clasificados  superdestacado" id="aviso-55172323">
#
#  	<input class="avisoInmoImg" data-error="//img10.naventcdn.com/css/img/placeholder-img.png" name="" type="hidden" value=" https://img10.naventcdn.com/empresas/18/00/50/28/76/97/80X48/logo_av-real-estate_1538526465548.jpg"/>
#  	<input class="avisoInmoCertif" name="" type="hidden" value=""/>
#  	<input class="avisoInmoTitle" name="" type="hidden" value="Av Real Estate"/>
#  	<input class="avisoInmoPhone" name="" type="hidden" value="99839"/>
#  	<input class="avisoInmoTipoAnunciante" name="" type="hidden" value="clasificados"/>
#  	<input class="avisoPrecio" name="" type="hidden" value="USD 375,000"/>
#
#  	<div class="aviso-tags">
#  			<span class="aviso-tags-superdestacado">
#
#  				Super destacado
#  			</span>
#  	</div>
#  	<div class="aviso-data">
#  		<div class="aviso-media">
#  			<span class="aviso-fav" data-aviso-id="55172323" data-component="nvt-add-fav">
#  				<i class="icon-fav"></i>
#  			</span>
#  			<div class="aviso-media-labels">
#  				<span class="aviso-media-labels-count label label-black label-black--transparent" data-count="11">1/11</span>
#
#
#  			</div>
#
#
#  <div class="picture-slider" data-aviso="55172323">
#  	<div class="listSlider loadThis js-TieneMapa js-SlideMapaInactivo" data-index-imagen="1" data-url-mapa="//maps.google.com/maps/api/staticmap?center=21.1148512,-86.76568939999999&amp;zoom=15&amp;markers=21.1148512,-86.76568939999999&amp;channel=I24&amp;size=720x532&amp;sensor=true&amp;scale=2&amp;key=AIzaSyBfTOxuYEmbL50_1P4KU8GI8toKT539agI&amp;signature=E2lyfYq3XGxq2UKzOD4CHha6d-k=">
#  		<div class="slide-content">
#  			<a class="jsUrlFichaMap map-slide display-block overslide-btn-contac" href="/propiedades/departamento-con-espectacular-vista-a-la-laguna-en-55172323.html#map">
#  				<img alt="" class="rsImg rsMainSlideImage mapImage" id="imgMap-55172323" src="..."/>
#  			</a>
#  		</div>
#
#  		<div class="slide-content">
#  			<img alt="Edificio" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/17/23/23/360x266/110742604.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Terraza" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/17/23/23/360x266/110742596.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Vista a la Laguna" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/17/23/23/360x266/110742601.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Vista al canal de la Laguna" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/17/23/23/360x266/110742603.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Estancia" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/17/23/23/360x266/110742598.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Estancia con vista a la laguna" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/17/23/23/360x266/110742600.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Pasillo" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/17/23/23/360x266/110742594.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Cocina" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/17/23/23/360x266/110742602.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Habitación con vista a la Laguna" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/17/23/23/360x266/110742597.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Habitación 1" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/17/23/23/360x266/110742599.jpg" src="..."/>
#  		</div>
#  		<div class="slide-content">
#  			<img alt="Habitación Principal" data-flickity-lazyload="https://img10.naventcdn.com/avisos/18/00/55/17/23/23/360x266/110742595.jpg" src="..."/>
#  		</div>
#  	</div>
#  </div>
#  <div class="aviso-main-photo-container">
#  		<button aria-label="previous" class="flickity-prev-next-button flickity-prev-next-button-temp previous" type="button"><svg viewBox="0 0 100 100"><path class="arrow" d="M 25,50 L 60,85 L 65,75 L 40,50  L 65,25 L 60,15 Z"></path></svg></button>
#  			<img class="aviso-main-photo lazyload" data-src="https://img10.naventcdn.com/avisos/18/00/55/17/23/23/360x266/110742604.jpg" src="..."/>
#  		<button aria-label="next" class="flickity-prev-next-button flickity-prev-next-button-temp next" type="button"><svg viewBox="0 0 100 100"><path class="arrow" d="M 25,50 L 60,85 L 65,75 L 40,50  L 65,25 L 60,15 Z" transform="translate(100, 100) rotate(180) "></path></svg></button>
#  	</div>
#
#
#  		</div>
#  		<div class="aviso-data-price">
#
#  	<div class="aviso-data-price-content">
#
#  	<span class="aviso-data-price-value">USD 375,000</span>
#
#
#
#
#  </div>
#
#  		</div>
#  	</div><!--
#  	--><div class="aviso-data aviso-data--right">
#  		<div class="aviso-data-content">
#  			<div class="aviso-data-head">
#  				<div class="aviso-data-text">
#  					<h4 class="aviso-data-title">
#  						<a class="dl-aviso-a" href="/propiedades/departamento-con-espectacular-vista-a-la-laguna-en-55172323.html" target="_blank" title="Departamento con espectacular vista a la laguna en Isla Dorada Cancún">
#  							Departamento con Espectacular Vista a La Laguna en Isla Dorada Cancún
#  						</a>
#  					</h4>
#  					<span class="aviso-data-location dl-aviso-link">
#  						Zona Hotelera Isla Dorada
#  							-
#  						<span>Zona Hotelera, Cancún</span>
#  					</span>
#  				</div>
#  				<div class="aviso-data-logos">
#  						<div class="aviso-data-logo">
#  							<img class="logo-inmobiliaria lazyload" data-src="https://img10.naventcdn.com/empresas/18/00/50/28/76/97/80X48/logo_av-real-estate_1538526465548.jpg" height="30" onerror="this.src='//img10.naventcdn.com/css/img/placeholder-img.png'" src="..." width="60"/>
#  						</div>
#
#  				</div>
#  			</div>
#  			<ul class="aviso-data-features dl-aviso-link">
#  							<li class="aviso-data-features-value">
#  								160 m²
#  								<span>
#  									construidos
#  								</span>
#  							</li>
#  						<li class="aviso-data-features-value">
#  							3
#  							<span>
#  									Recámaras
#  							</span>
#  						</li>
#  						<li class="aviso-data-features-value">
#  							2
#  							<span>
#  									Baños
#  							</span>
#  						</li>
#  			</ul>
#  			<p class="aviso-data-description dl-aviso-link">
#  				Departamento en condominio en Isla Dorada, un exclusivo residencial en donde podrá disfrutar de las hermosas vistas a la laguna y a los canales, una zona muy exclusiva en Cancún con una alta plusvalía. El condominio cuenta con solo 27 unidades, podrá disfrutar su hermosa alberca con vista a la laguna, cuenta con muelle para embarcaciones, además de que tiene Casa Club dentro del residencial donde podrá disfrutar de alberca, campo de tenis, jacuzzi, gimnasio, spa y un salón de eventos. Características principales. - 160 m2. - Estancia amplia con ventanal. - Cocina equipada. - 3 Habitaciones. - 2 Baños completos. - Hermosa Terraza. - 2 Estacionamientos. - Aire acondicionado central. - Ventiladores. - Cortinas anticiclónicas. - Muebles de madera. - En el 1er Nivel. - Muelle para embarcaciones. - Excelentes condiciones
#  			</p>
#
#  			<div class="aviso-data-extra">
#  				<ul class="aviso-data-extra-ul">
#
#  				</ul>
#  			</div>
#  			<div class="aviso-data-cta">
#  				<div class="pull-right">
#  					<!-- primary CTA -->
#
#  					<button class="contactar-btn btn btn-card btn-aviso js-contact" data-aviso-id="55172323" data-tipo-anunciante="clasificados">
#  						Contactar
#  					</button>
#
#  					<button class="recontactar-btn btn btn-card btn-aviso js-contact" data-aviso-id="55172323" data-tipo-anunciante="clasificados">
#  						volver a contactar
#  					</button>
#  					<!-- directorio CTA -->
#  					<a class="btn btn-card btn-inmo dl-aviso-link" href="/propiedades/departamento-con-espectacular-vista-a-la-laguna-en-55172323.html" title="Departamento con espectacular vista a la laguna en Isla Dorada Cancún">
#  						ver detalles
#  					</a>
#  				</div>
#  			</div>
#  		</div>
#  	</div>
#  </li>]

# %% [markdown]
# ## Get the prices

# %%
prices = []

for li in main_list:
    price = li.find('span', attrs={"class": "aviso-data-price-value"})
    prices.append(format_price(price))
prices
# Out:
# [25135650,
#  5300000,
#  6579000,
#  13932000,
#  7950000,
#  9000000,
#  10642500,
#  9094500,
#  7740000,
#  42570000,
#  46440000,
#  6600000,
#  9400000,
#  5031000,
#  5418000,
#  49342500,
#  7256250]

# %% [markdown]
# ## Get the titles

# %%
titles = []

for li in main_list:
    title = li.find('a', attrs={'class': 'dl-aviso-a'})
    titles.append(format_title(title))
titles
# Out:
# ['Sensacional Departamento en Zona Hotelera de Cancun',
#  'Departamento en Venta en Poktapok',
#  'Departamentos en Venta en Cancun Zona Hotelera',
#  'Espectacular Oportunidad en Residencial Bvg Cancun en La Orilla del Mar Caribe',
#  'Exclusivo Pent Garden Isla Dorada 3 Recamaras',
#  'Allure Ocean Front Luxury Condos – Puerto Cancun',
#  'Preventa en Puerto Cancún D',
#  'Departamentos en Venta en Isla Dorada Cancun',
#  'Departamento en Venta, Isla Bonita, Zona Hotelera, Cancun',
#  'Departamento en Venta Emerald, Zona Hotelera, Cancun',
#  'Departamento en Venta en Cancun Zona Hotelera',
#  'Departamento en Venta, Isla Bonita, Zona Hotelera, Cancun',
#  'Departamento en Venta Vista Al Mar.',
#  'Penthouse Frente Al Mar en Venta! C2262',
#  'Departamento en Venta, Isla Bonita, Zona Hotelera, Cancun',
#  'Departamentos en Venta en Cancun Zona Hotelera',
#  'Departamento con Espectacular Vista a La Laguna en Isla Dorada Cancún']

# %% [markdown]
# ## Get the square meters

# %%
square_meters = []

for li in main_list:
    square_meters_tag = li.find('li', attrs={"class": "aviso-data-features-value"})
    square_meters.append(get_square_meters(square_meters_tag))

square_meters
# Out:
# [285,
#  140,
#  142,
#  185,
#  220,
#  224,
#  154,
#  235,
#  161,
#  390,
#  370,
#  190,
#  220,
#  88,
#  142,
#  365,
#  160]

# %%
df = pd.DataFrame({'titles': titles,
                   'prices_mxn': prices,
                   'square_meters': square_meters})
df
# Out:
#                                                titles  prices_mxn  \
# 0   Sensacional Departamento en Zona Hotelera de C...    25135650
# 1                   Departamento en Venta en Poktapok     5300000
# 2      Departamentos en Venta en Cancun Zona Hotelera     6579000
# 3   Espectacular Oportunidad en Residencial Bvg Ca...    13932000
# 4       Exclusivo Pent Garden Isla Dorada 3 Recamaras     7950000
# 5    Allure Ocean Front Luxury Condos – Puerto Cancun     9000000
# 6                         Preventa en Puerto Cancún D    10642500
# 7        Departamentos en Venta en Isla Dorada Cancun     9094500
# 8   Departamento en Venta, Isla Bonita, Zona Hotel...     7740000
# 9   Departamento en Venta Emerald, Zona Hotelera, ...    42570000
# 10      Departamento en Venta en Cancun Zona Hotelera    46440000
# 11  Departamento en Venta, Isla Bonita, Zona Hotel...     6600000
# 12                Departamento en Venta Vista Al Mar.     9400000
# 13            Penthouse Frente Al Mar en Venta! C2262     5031000
# 14  Departamento en Venta, Isla Bonita, Zona Hotel...     5418000
# 15     Departamentos en Venta en Cancun Zona Hotelera    49342500
# 16  Departamento con Espectacular Vista a La Lagun...     7256250
#
#     square_meters
# 0             285
# 1             140
# 2             142
# 3             185
# 4             220
# 5             224
# 6             154
# 7             235
# 8             161
# 9             390
# 10            370
# 11            190
# 12            220
# 13             88
# 14            142
# 15            365
# 16            160

# %%
df['price_per_square_meter'] = np.floor(df['prices_mxn'] /  df['square_meters'])

# %%
df
# Out:
#                                                titles  prices_mxn  \
# 0   Sensacional Departamento en Zona Hotelera de C...    25135650
# 1                   Departamento en Venta en Poktapok     5300000
# 2      Departamentos en Venta en Cancun Zona Hotelera     6579000
# 3   Espectacular Oportunidad en Residencial Bvg Ca...    13932000
# 4       Exclusivo Pent Garden Isla Dorada 3 Recamaras     7950000
# 5    Allure Ocean Front Luxury Condos – Puerto Cancun     9000000
# 6                         Preventa en Puerto Cancún D    10642500
# 7        Departamentos en Venta en Isla Dorada Cancun     9094500
# 8   Departamento en Venta, Isla Bonita, Zona Hotel...     7740000
# 9   Departamento en Venta Emerald, Zona Hotelera, ...    42570000
# 10      Departamento en Venta en Cancun Zona Hotelera    46440000
# 11  Departamento en Venta, Isla Bonita, Zona Hotel...     6600000
# 12                Departamento en Venta Vista Al Mar.     9400000
# 13            Penthouse Frente Al Mar en Venta! C2262     5031000
# 14  Departamento en Venta, Isla Bonita, Zona Hotel...     5418000
# 15     Departamentos en Venta en Cancun Zona Hotelera    49342500
# 16  Departamento con Espectacular Vista a La Lagun...     7256250
#
#     square_meters  price_per_square_meter
# 0             285                 88195.0
# 1             140                 37857.0
# 2             142                 46330.0
# 3             185                 75308.0
# 4             220                 36136.0
# 5             224                 40178.0
# 6             154                 69107.0
# 7             235                 38700.0
# 8             161                 48074.0
# 9             390                109153.0
# 10            370                125513.0
# 11            190                 34736.0
# 12            220                 42727.0
# 13             88                 57170.0
# 14            142                 38154.0
# 15            365                135184.0
# 16            160                 45351.0

# %% [markdown]
# ## The average of the prices

# %%
math.floor(df['prices_mxn'].mean())
# Out:
# 15731258

# %% [markdown]
# ## The average of the prices per square meter

# %%
math.floor(df['price_per_square_meter'].mean())
# Out:
# 62816

# %% [markdown]
# ## Write the Dataframe to Postgres table

# %%
df.to_sql('aparments', engine, if_exists='replace')

# %%
engine.execute("SELECT * FROM aparments").fetchall()
# Out:
# [(0, 'Sensacional Departamento en Zona Hotelera de Cancun', 25135650, 285, 88195.0),
#  (1, 'Departamento en Venta en Poktapok', 5300000, 140, 37857.0),
#  (2, 'Departamentos en Venta en Cancun Zona Hotelera', 6579000, 142, 46330.0),
#  (3, 'Espectacular Oportunidad en Residencial Bvg Cancun en La Orilla del Mar Caribe', 13932000, 185, 75308.0),
#  (4, 'Exclusivo Pent Garden Isla Dorada 3 Recamaras', 7950000, 220, 36136.0),
#  (5, 'Allure Ocean Front Luxury Condos – Puerto Cancun', 9000000, 224, 40178.0),
#  (6, 'Preventa en Puerto Cancún D', 10642500, 154, 69107.0),
#  (7, 'Departamentos en Venta en Isla Dorada Cancun', 9094500, 235, 38700.0),
#  (8, 'Departamento en Venta, Isla Bonita, Zona Hotelera, Cancun', 7740000, 161, 48074.0),
#  (9, 'Departamento en Venta Emerald, Zona Hotelera, Cancun', 42570000, 390, 109153.0),
#  (10, 'Departamento en Venta en Cancun Zona Hotelera', 46440000, 370, 125513.0),
#  (11, 'Departamento en Venta, Isla Bonita, Zona Hotelera, Cancun', 6600000, 190, 34736.0),
#  (12, 'Departamento en Venta Vista Al Mar.', 9400000, 220, 42727.0),
#  (13, 'Penthouse Frente Al Mar en Venta! C2262', 5031000, 88, 57170.0),
#  (14, 'Departamento en Venta, Isla Bonita, Zona Hotelera, Cancun', 5418000, 142, 38154.0),
#  (15, 'Departamentos en Venta en Cancun Zona Hotelera', 49342500, 365, 135184.0),
#  (16, 'Departamento con Espectacular Vista a La Laguna en Isla Dorada Cancún', 7256250, 160, 45351.0)]
